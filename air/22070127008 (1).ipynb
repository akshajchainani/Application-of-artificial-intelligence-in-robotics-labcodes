# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Naive Bayes
#Bayes Theorem
#P(y/x)= (P(x/y) * P(y))/P(x)

# %%
#Experiment 3: Write a program to implement the naive bayesin classifier for the sample training dataset stored in the .csv file

# %%
df= pd.read_csv("/content/drive/MyDrive/Datasets AIR/User_Data.csv")
df
# Out:
#       User ID  Gender  Age  EstimatedSalary  Purchased
# 0    15624510    Male   19            19000          0
# 1    15810944    Male   35            20000          0
# 2    15668575  Female   26            43000          0
# 3    15603246  Female   27            57000          0
# 4    15804002    Male   19            76000          0
# ..        ...     ...  ...              ...        ...
# 395  15691863  Female   46            41000          1
# 396  15706071    Male   51            23000          1
# 397  15654296  Female   50            20000          1
# 398  15755018    Male   36            33000          0
# 399  15594041  Female   49            36000          1
#
# [400 rows x 5 columns]

# %%
#select age and estimated salary as input(dependent variable) predict if a person has made a purchase or not
x= df.iloc[:,[2,3]]
x
# Out:
#      Age  EstimatedSalary
# 0     19            19000
# 1     35            20000
# 2     26            43000
# 3     27            57000
# 4     19            76000
# ..   ...              ...
# 395   46            41000
# 396   51            23000
# 397   50            20000
# 398   36            33000
# 399   49            36000
#
# [400 rows x 2 columns]

# %%
#select "purchased" as the target variable
y= df.iloc[:,[-1]]
y
# Out:
#      Purchased
# 0            0
# 1            0
# 2            0
# 3            0
# 4            0
# ..         ...
# 395          1
# 396          1
# 397          1
# 398          0
# 399          1
#
# [400 rows x 1 columns]

# %%
#splitting the dataset into the training and test set
from sklearn.model_selection import train_test_split
x_train, x_test,y_train, y_test= train_test_split(x,y,test_size= 0.3,random_state=40)

# %%
#feature scaling
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
scaled_x_train = scaler.fit_transform(x_train)
scaled_x_test= scaler.fit_transform(x_test)

# %%
#use naive bayes algorithm for classification
from sklearn.naive_bayes import GaussianNB
classifier= GaussianNB()
classifier.fit(scaled_x_train, y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# GaussianNB()

# %%
#predicitng the test results
y_pred = classifier.predict(scaled_x_test)

# %%
#making confusion matrix
from sklearn.metrics import confusion_matrix
cm= confusion_matrix(y_test, y_pred)
cm
# Out:
# array([[74,  3],
#        [12, 31]])

# %%
#accuracy= correct prediction/total no of prediction
#accuracy = (74/120)*100= 61%

# %%
#error rate = wrong prediction/total prediction
#error rate = (15/120)*100 = 12.5%
