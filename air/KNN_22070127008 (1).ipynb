# %%
import numpy as np
import pandas as pd

# %%
from sklearn.impute import KNNImputer

# %%
df = {'Maths': [85,91,np.nan, 91],
      'Chemistry': [72,75,74,np.nan],
      'Physics': [np.nan,68,82,81],
      'Biology': [81,81,72,np.nan]}

# %%
Bef_impute = pd.DataFrame(df)
Bef_impute
# Out:
#    Maths  Chemistry  Physics  Biology
# 0   85.0       72.0      NaN     81.0
# 1   91.0       75.0     68.0     81.0
# 2    NaN       74.0     82.0     72.0
# 3   91.0        NaN     81.0      NaN

# %% [markdown]
# Converting to CSV

# %%
Bef_impute.to_csv('/content/drive/MyDrive/Dataster_AAI/Bef_impute')

# %% [markdown]
# Repalcing empty cells
#
#
# ---
#
#
#
# ---

# %%
imputer = KNNImputer(n_neighbors=2)
After_imputation = imputer.fit_transform(Bef_impute)
After_imputation
# Out:
# array([[85. , 72. , 74.5, 81. ],
#        [91. , 75. , 68. , 81. ],
#        [88. , 74. , 82. , 72. ],
#        [91. , 73. , 81. , 76.5]])

# %% [markdown]
# Convert array to dataframe

# %%
af = pd.DataFrame(After_imputation,columns = ['Maths','Chemistry','Physics','Biology'])
af
# Out:
#    Maths  Chemistry  Physics  Biology
# 0   85.0       72.0     74.5     81.0
# 1   91.0       75.0     68.0     81.0
# 2   88.0       74.0     82.0     72.0
# 3   91.0       73.0     81.0     76.5

# %%
dz={'Name': ['Root','Stark','John','Marsh','Sam'],'Age': [31, 34, 33, 35,32],'Department': ['Navy','Army',np.nan,'Navy',np.nan],'Color_Code': ['white', 'Green', 'White',np.nan,'White']}

# %%
dz=pd.DataFrame(dz)
dz
# Out:
#     Name  Age Department Color_Code
# 0   Root   31       Navy      white
# 1  Stark   34       Army      Green
# 2   John   33        NaN      White
# 3  Marsh   35       Navy        NaN
# 4    Sam   32        NaN      White

# %%
dz.to_csv('/content/drive/MyDrive/Dataster_AAI/dz')

# %%
dz.columns
# Out:
# Index(['Name', 'Age', 'Department', 'Color_Code'], dtype='object')

# %%
dz
dz['Department_map']=dz.Department.map({'Navy':0,'Army':1})
dz['Color_Code_map']=dz.Color_Code.map({'White':0,'Green':1})

# %%
dz
# Out:
#     Name  Age Department Color_Code  Department_map  Color_Code_map
# 0   Root   31       Navy      white             0.0             NaN
# 1  Stark   34       Army      Green             1.0             1.0
# 2   John   33        NaN      White             NaN             0.0
# 3  Marsh   35       Navy        NaN             0.0             NaN
# 4    Sam   32        NaN      White             NaN             0.0

# %%
dz1=dz[['Age','Department_map']]
dz1
# Out:
#    Age  Department_map
# 0   31             0.0
# 1   34             1.0
# 2   33             NaN
# 3   35             0.0
# 4   32             NaN
